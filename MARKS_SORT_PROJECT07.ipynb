# %% [markdown]
# <a href="https://colab.research.google.com/github/Eakansh249120/THAPAR_MINI_PROJECT07/blob/main/MARKS_SORT_PROJECT07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marks_df=pd.read_csv('Marks.csv')
marks_df

marks_df.value_counts().head()
marks_df.groupby(['Roll Num','Marks']).size().reset_index()
# Out:
#       Roll Num  Marks  0
# 0    102003001      0  1
# 1    102003001      1  3
# 2    102003002      1  5
# 3    102003017      1  5
# 4    102003018      1  5
# ..         ...    ... ..
# 458  102197016      1  5
# 459  102197018      0  1
# 460  102197018      1  4
# 461  102197019      1  5
# 462  102197021      1  5
#
# [463 rows x 3 columns]
